# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-02-20 16:28:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   218MB/s    in 0.3s
#
# 2023-02-20 16:28:05 (218 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6452   1702.03334v1  We study reinforcement learning of chatbots wi...  stat
# 10168  1710.02543v2  We present an approach for mobile robots to le...    cs
# 27403  1703.05630v2  Junctions play an important role in the charac...    cs
# 36401   1305.6037v1  In this paper the theory of semi-bounded ratio...    cs
# 21783  1505.01582v2  Hypergraph partitioning lies at the heart of a...  stat
# ...             ...                                                ...   ...
# 22110   1412.2295v2  We propose a likelihood ratio based inferentia...  stat
# 1449   1506.08126v1  The New Yorker publishes a weekly captionless ...    cs
# 9615    1208.2651v1  In a context where most published articles are...  stat
# 5587    1303.6977v4  This paper introduces a simple, general framew...  stat
# 39481  1606.05703v1  Most satellites decouple the acquisition of a ...    cs
#
#                                                    title  year  \
# 6452   Batch Policy Gradient Methods for Improving Ne...  2017
# 10168  Socially Compliant Navigation through Raw Dept...  2017
# 27403  Anisotropic-Scale Junction Detection and Match...  2017
# 36401  Semi-bounded Rationality: A model for decision...  2013
# 21783  Consistency of Spectral Hypergraph Partitionin...  2015
# ...                                                  ...   ...
# 22110  A Likelihood Ratio Framework for High Dimensio...  2014
# 1449   Humor in Collective Discourse: Unsupervised Fu...  2015
# 9615   A Plea for Neutral Comparison Studies in Compu...  2012
# 5587                          ABC Reinforcement Learning  2013
# 39481  A Survey of Pansharpening Methods with A New B...  2016
#
#                                                 keywords
# 6452   [reinforcement, recurrent, architectures, expe...
# 10168  [environments, pedestrians, compliant, generat...
# 27403  [junctions, important, characterization, geome...
# 36401  [rationality, extension, rationality, particul...
# 21783  [hypergraph, partitioning, algorithms, hypergr...
# ...                                                  ...
# 22110  [likelihood, inferential, framework, dimension...
# 1449   [publishes, captionless, experiment, automatic...
# 9615   [published, development, comparison, generally...
# 5587   [introduces, framework, likelihood, reinforcem...
# 39481  [satellites, acquisition, panchromatic, resolu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6452     [reinforcement, recurrent, architectures, expe...
# 10168    [environments, pedestrians, compliant, generat...
# 27403    [junctions, important, characterization, geome...
# 36401    [rationality, extension, rationality, particul...
# 21783    [hypergraph, partitioning, algorithms, hypergr...
#                                ...
# 22439    [interesting, nomination, remaining, nominatio...
# 16573    [character, perplexity, parameters, character,...
# 11711    [statistical, inference, providing, estimation...
# 31017    [stressful, countries, railroads, penalized, l...
# 34295    [verification, vulnerable, different, synthesi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8999 words.
# Out of those 4615 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="28e8dcb6-071f-4579-b360-8b9fcf0cbf8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28e8dcb6-071f-4579-b360-8b9fcf0cbf8b")) {                    Plotly.newPlot(                        "28e8dcb6-071f-4579-b360-8b9fcf0cbf8b",                        [{"x":["expensive","experiment","consuming","strategies","mechanical","empirically","experiments","reinforcement","appropriate","demonstrate","conversation","improving","assurance","processing","synthetic","recurrent","recommendations","automated","restaurant","architectures","computation","pedestrian","compliant","disadvantages","pedestrians","deployment","environments","adversarial","autonomous","navigation","knowledge","efficiency","behaviors","generative","information","imitation","overcomes","extraction","simulation","geometries","locations","important","detection","anisotropic","longstanding","identifying","parameter","orientations","associated","characterization","independent","estimates","detectors","structures","geometric","distinctive","challenging","viewpoint","performance","junctions","insufficiently","precision","artificial","imperfect","incomplete","limitations","rationality","components","consistent","inconsistent","extension","irrespective","correlation","intelligence","intelligent","decisions","particular","attention","theoretical","extensive","consistency","partition","generalizes","guarantees","concentration","approaches","literature","algorithm","inequalities","hypergraphs","hypergraph","partitioning","stochastic","algorithms","competitive","additional","combining","complexity","generated","conjunction","interaction","experimental","furthermore","statistical","investigated","alternative","therefore","nonlinear","generalization","mechanism","complicated","effectiveness","privileged","illustrate","rademacher","functional","naturally","practical","theoretic","properties","structure","interpolates","observations","observing","partially","observation","invariant","advantage","compression","definition","classical","characteristics","interface","optimization","robustness","translation","intensity","description","stitching","panoramic","according","eventually","inference","outperforms","expression","shrinkage","statistically","application","undersampling","inferring","estimation","generating","effective","association","simplicity","specifically","dimensional","resulting","procedure","analyzing","scenarios","available","computationally","estimator","computing","implements","procedures","efficient","weaknesses","prediction","regression","attribute","progresses","introducing","predicting","individual","combinations","sentiment","techniques","formulation","different","comparison","conventional","applications","decomposition","inappropriate","characterized","substantial","quantization","factorization","especially","suitability","evaluated","formulations","recognition","convolutional","automatically","accurately","pertaining","continuous"],"y":[65,76,38,96,11,69,577,95,76,520,16,108,2,286,129,150,18,105,1,124,151,16,3,11,9,17,65,113,55,27,363,180,27,125,682,14,16,137,74,3,47,348,366,9,7,70,113,11,104,37,131,78,40,140,69,12,260,26,888,4,3,70,138,9,26,68,10,102,65,13,73,3,75,111,65,55,262,176,155,172,54,30,28,64,15,425,138,789,3,5,2,17,117,594,112,134,101,222,168,13,70,421,179,165,47,85,160,53,107,100,27,191,2,88,4,39,47,144,38,211,338,2,92,21,48,62,56,97,49,38,104,100,29,329,100,100,35,80,3,3,107,12,198,236,48,4,20,229,2,25,192,94,248,22,23,155,173,153,125,60,100,300,90,29,134,15,23,377,15,214,97,38,7,58,75,107,32,42,360,70,778,139,101,386,71,9,29,50,24,31,111,6,150,23,400,376,177,61,4,93],"type":"bar"},{"x":["expensive","experiment","consuming","strategies","mechanical","empirically"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4615,), (4615, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8225

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Self</span> <span style=''>Adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hierarchical</span> <span style=''>Sentence</span> <span style=''>Model</span> <br/><br/><span style=''>The</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accurately</span> <span style=''>model</span> <span style=''>a</span> <span style=''>sentence</span> <span style=''>at</span> <span style=''>varying</span> <span style=''>stages</span> <span style=''>(eg</span> <span style=''>word</span> <span style=''>phrase</span> <span style=''>sentence)</span> <span style=''>plays</span> <span style=''>a</span> <span style=''>central</span> <span style=''>role</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.44080604534005036);'>processing</span> <span style=''>As</span> <span style=''>an</span> <span style=''>effort</span> <span style=''>towards</span> <span style=''>this</span> <span style=''>goal</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>self</span> <span style=''>adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style=''>sentence</span> <span style=''>model</span> <span style=''>(AdaSent)</span> <span style=''>AdaSent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effectively</span> <span style=''>forms</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5769230769230769);'>hierarchy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representations</span> <span style=''>from</span> <span style=''>words</span> <span style=''>to</span> <span style=''>phrases</span> <span style=''>and</span> <span style=''>then</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.8909090909090909);'>sentences</span> <span style=''>through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recursive</span> <span style=''>gated</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>composition</span> <span style=''>of</span> <span style=''>adjacent</span> <span style=''>segments</span> <span style=''>We</span> <span style=''>design</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitive</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>mechanism</span> <span style=''>(through</span> <span style=''>gating</span> <span style=''>networks)</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>same</span> <span style=''>sentence</span> <span style=''>to</span> <span style=''>be</span> <span style=''>engaged</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>learning</span> <span style=''>task</span> <span style=''>(eg</span> <span style=''>classification)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effectively</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mitigating</span> <span style=''>the</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>vanishing</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>persistent</span> <span style=''>in</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recursive</span> <span style=''>models</span> <span style=''>Both</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>qualitative</span> <span style=''>and</span> <span style='ba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Feedback</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>for</span> <span style=''>Live</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictors</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>that</span> <span style=''>is</span> <span style=''>deployed</span> <span style=''>in</span> <span style=''>a</span> <span style=''>live</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>production</span> <span style=''>system</span> <span style=''>may</span> <span style=''>perturb</span> <span style=''>the</span> <span style=''>features</span> <span style=''>it</span> <span style=''>uses</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>Such</span> <span style=''>a</span> <span style=''>feedback</span> <span style=''>loop</span> <span style=''>can</span> <span style=''>occur</span> <span style=''>for</span> <span style=''>example</span> <span style=''>when</span> <span style=''>a</span> <span style=''>model</span> <span style=''>that</span> <span style=''>predicts</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>type</span> <span style=''>of</span> <span style=''>behavior</span> <span style=''>ends</span> <span style=''>up</span> <span style=''>causing</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>it</span> <span style=''>predicts</span> <span style=''>thus</span> <span style=''>creating</span> <span style=''>a</span> <span style=''>self</span> <span style=''>fulfilling</span> <span style=''>prophecy</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>analyze</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>feedback</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>as</span> <span style=''>a</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>problem</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomization</span> <span style=''>scheme</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>feedback</span> <span style=''>in</span> <span style=''>real</span> <span style=''>world</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>conduct</span> <span style=''>a</span> <span style=''>pilot</span> <span style=''>study</span> <span style=''>for</span> <span style=''>our</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>currently</span> <span style=''>deployed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>part</span> <span style=''>of</span> <span style=''>a</span> <span style=''>search</span> <span style=''>engine</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>and</span> <span style=''>Strong</span> <span style='background-color:rgba(255, 0, 0, 0.3493975903614459);'>Convergence</span> <span style=''>of</span> <span style=''>Online</span> <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>online</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>without</span> <span style=''>explicit</span> <span style='background-color:rgba(255, 0, 0, 0.31304347826086953);'>regularization</span> <span style=''>terms</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essentially</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.4207920792079208);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>scheme</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.6603773584905661);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>(RKHS)</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomially</span> <span style=''>decaying</span> <span style=''>step</span> <span style=''>size</span> <span style=''>in</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>can</span> <span style=''>play</span> <span style=''>a</span> <span style=''>role</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.31304347826086953);'>regularization</span> <span style=''>to</span> <span style=''>ensure</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>ability</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>capacity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>analysis</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>last</span> <span style=''>iterate</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contribution</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>two</span> <span style=''>fold</span> <span style=''>First</span> <span style=''>our</span> <span style=''>nice</span> <span style=''>analysis</span> <span style=''>can</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3493975903614459);'>convergence</span> <span style=''>rate</span> <span style=''>in</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>mean</span> <span style=''>square</span> <span style=''>distance</span> <span style=''>which</span> <span style=''>is</span> <span style=''>the</span> <span style=''>best</span> <span style=''>so</span> <span style=''>far</span> <span style=''>Second</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.30303030303030304);'>establish</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Discriminative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Similarity</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>and</span> <span style=''>Semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Similarity</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>separate</span> <span style=''>the</span> <span style=''>data</span> <span style=''>into</span> <span style=''>clusters</span> <span style=''>or</span> <span style=''>classes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>according</span> <span style=''>to</span> <span style=''>the</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>between</span> <span style=''>the</span> <span style=''>data</span> <span style=''>and</span> <span style=''>the</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>is</span> <span style=''>crucial</span> <span style=''>for</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>which</span> <span style=''>learns</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>for</span> <span style=''>either</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>or</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>learns</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>from</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothetical</span> <span style=''>labeling</span> <span style=''>and</span> <span style=''>searches</span> <span style=''>for</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>labeling</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothetical</span> <span style=''>labeling</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>is</span> <span style=''>employed</span> <span style=''>in</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>By ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08461263834344877)
# 	information (0.2434844698322028)
# 	knowledge (0.12959657265262406)
# 	representation (0.13173866476258478)
# 	segmentation (0.07604426990360585)
# 	experimental (0.1503034630489111)
# 	detection (0.13066761870760443)
# 	different (0.27775794359157446)
# 	convolutional (0.13423777222420563)
# 	recognition (0.14280614066404856)
#
# Some Statistics words are:
# 	statistical (0.14607303651825912)
# 	variables (0.135567783891946)
# 	theoretical (0.15157578789394696)
# 	algorithm (0.38219109554777386)
# 	stochastic (0.14357178589294647)
# 	distribution (0.18159079539769885)
# 	estimation (0.17708854427213608)
# 	dimensional (0.18109054527263632)
# 	inference (0.2066033016508254)
# 	regression (0.17558779389694848)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2778882e-4b45-4dd5-a4fe-3b525b015b13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2778882e-4b45-4dd5-a4fe-3b525b015b13")) {                    Plotly.newPlot(                        "2778882e-4b45-4dd5-a4fe-3b525b015b13",                        [{"x":["expensive","experiment","consuming","strategies","mechanical","empirically","experiments","reinforcement","appropriate","demonstrate","conversation","improving","assurance","processing","synthetic","recurrent","recommendations","automated","restaurant","architectures","computation","pedestrian","compliant","disadvantages","pedestrians","deployment","environments","adversarial","autonomous","navigation","knowledge","efficiency","behaviors","generative","information","imitation","overcomes","extraction","simulation","geometries","locations","important","detection","anisotropic","longstanding","identifying","parameter","orientations","associated","characterization","independent","estimates","detectors","structures","geometric","distinctive","challenging","viewpoint","performance","junctions","insufficiently","precision","artificial","imperfect","incomplete","limitations","rationality","components","consistent","inconsistent","extension","irrespective","correlation","intelligence","intelligent","decisions","particular","attention","theoretical","extensive","consistency","partition","generalizes","guarantees","concentration","approaches","literature","algorithm","inequalities","hypergraphs","hypergraph","partitioning","stochastic","algorithms","competitive","additional","combining","complexity","generated","conjunction","interaction","experimental","furthermore","statistical","investigated","alternative","therefore","nonlinear","generalization","mechanism","complicated","effectiveness","privileged","illustrate","rademacher","functional","naturally","practical","theoretic","properties","structure","interpolates","observations","observing","partially","observation","invariant","advantage","compression","definition","classical","characteristics","interface","optimization","robustness","translation","intensity","description","stitching","panoramic","according","eventually","inference","outperforms","expression","shrinkage","statistically","application","undersampling","inferring","estimation","generating","effective","association","simplicity","specifically","dimensional","resulting","procedure","analyzing","scenarios","available","computationally","estimator","computing","implements","procedures","efficient","weaknesses","prediction","regression","attribute","progresses","introducing","predicting","individual","combinations","sentiment","techniques","formulation","different","comparison","conventional","applications","decomposition","inappropriate","characterized","substantial","quantization","factorization","especially","suitability","evaluated","formulations","recognition","convolutional","automatically","accurately","pertaining","continuous","labelling","utilizing","arbitrary","laborious","competition","detecting","fundamental","architecture","requiring","modifying","localisation","surprisingly","establishes","averaging","providing","computational","parallelization","differences","generalizing","stepsizes","operators","introduced","characterizes","asymptotic","parallelizing","significantly","dependent","developing","parallelizable","involving","approximation","characterize","decentralized","formulate","programming","benchmark","combinatorial","formulating","experience","mathematical","representation","represent","obtaining","technique","empirical","classification","concisely","distribution","categories","resampling","bootstrap","replacement","heuristic","generalisation","researchers","inv ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	stepsizes
# 	confounders
# 	particulars
# 	missforest
# 	newsvendor
# 	pseudolikelihood
# 	replicates
# 	cytometry
# 	logarithmically
# 	sandwiched
# 	conditionally
# 	diverging
# 	businesses
# 	monetization
# 	conversely
# 	retention
# 	asymptotics
# 	behaviorally
# 	concordance
# 	heteroscedastic
# Some words which never appear in Statistics papers:
# 	compliant
# 	longstanding
# 	junctions
# 	insufficiently
# 	imperfect
# 	milestone
# 	designation
# 	cryptanalysis
# 	formalisms
# 	adjective
# 	transcriptions
# 	concatenations
# 	spontaneous
# 	affective
# 	monocular
# 	household
# 	appliances
# 	recombination
# 	structuring
# 	differentiated

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.065134099616859e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7883333333333333
